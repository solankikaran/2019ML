# %%
import pandas as pd

# %%
df = pd.read_csv('employees.csv', parse_dates=["Start Date", "Last Login Time"])
df['Senior Management'] = df['Senior Management'].astype(bool)
df.sort_values('First Name', inplace=True)
df['Gender'] = df['Gender'].astype("category")

# %%
len(df)
# Out:
# 1000

# %%
len(df.drop_duplicates()) ##WTF?
# Out:
# 1000

# %% [markdown]
# ## Wondering wth was that? Explanation:->
# Thing is. drop_duplicates should match everything. Only Aaron matches but when you see Start Date and Last login, they dont match

# %%
df.drop_duplicates(subset=['First Name'], keep='first') #Drops duplicate values
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2019-01-31 10:20:00   61602   11.849
# 137       Adam    Male 2011-05-21 2019-01-31 01:45:00   95327   15.120
# 300       Alan    Male 1988-06-26 2019-01-31 03:54:00  111786    3.592
# 372     Albert    Male 1997-02-01 2019-01-31 16:20:00   67827   19.717
# 988      Alice  Female 2004-10-05 2019-01-31 09:34:00   47638   11.209
# 639     Amanda     NaN 1991-08-11 2019-01-31 14:15:00   46665   19.391
# 879        Amy  Female 2009-05-20 2019-01-31 06:26:00   75415   19.132
# 430     Andrea  Female 2010-10-01 2019-01-31 11:54:00   79123   19.422
# 564     Andrew    Male 1985-03-29 2019-01-31 18:57:00   43414    7.563
# 8       Angela  Female 2005-11-22 2019-01-31 06:29:00   95570   18.523
# 509        Ann  Female 1984-11-04 2019-01-31 12:17:00   90719    6.220
# 645       Anna     NaN 1985-03-13 2019-01-31 09:19:00   45418   10.162
# ...

# %%
len(df.drop_duplicates(subset=['First Name'], keep='first'))
# Out:
# 201
