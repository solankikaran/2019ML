# %%
import pandas as pd

# %%
df = pd.read_csv('employees.csv', parse_dates=["Start Date", "Last Login Time"])
df['Senior Management'] = df['Senior Management'].astype(bool)
df['Gender'] = df['Gender'].astype("category")

# %%
mask1 = df['Gender'] == 'Male'

mask2 = df['Team'] == 'Marketing'

df[mask1 & mask2]

#This snippet of code returns people who are male and are in marketing with & operator
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2019-01-31 12:42:00   97308    6.945
# 21     Matthew   Male 1995-09-05 2019-01-31 02:12:00  100612   13.645
# 26       Craig   Male 2000-02-27 2019-01-31 07:45:00   37598    7.757
# 74      Thomas   Male 1995-06-04 2019-01-31 14:24:00   62096   17.029
# 77     Charles   Male 2004-09-14 2019-01-31 20:13:00  107391    1.260
# 101      Aaron   Male 2012-02-17 2019-01-31 10:20:00   61602   11.849
# 104       John   Male 1989-12-23 2019-01-31 07:01:00   80740   19.305
# 112     Willie   Male 2003-11-27 2019-01-31 06:21:00   64363    4.023
# 119       Paul   Male 2008-06-03 2019-01-31 15:05:00   41054   12.299
# 150       Sean   Male 1996-05-04 2019-01-31 20:59:00  135490   19.934
# 187      Roger   Male 2004-11-19 2019-01-31 15:55:00   51430    6.460
# 204     Willie   Male 2006-06-06 2019-01-31 09:45:00   55281    4.935
# ...

# %% [markdown]
# ### For the code to work both conditions should be satisfied for & operator.

# %%
mask3 = df['Senior Management']

mask4 = df['Start Date'] < '1990-01-01'

# %%
df[mask3 | mask4].head() #Pipe operator is used to ORing
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06 2019-01-31 12:42:00   97308    6.945
# 1     Thomas   Male 1996-03-31 2019-01-31 06:53:00   61933    4.170
# 3      Jerry   Male 2005-03-04 2019-01-31 13:00:00  138705    9.340
# 4      Larry   Male 1998-01-24 2019-01-31 16:47:00  101004    1.389
# 5     Dennis   Male 1987-04-18 2019-01-31 01:35:00  115163   10.125
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 3               True          Finance
# 4               True  Client Services
# 5              False            Legal

# %%
mask5 = df['First Name'] == 'Robert'
mask6 = df['Team'] == 'Client Services'
mask7 = df['Start Date'] > '2016-06-01'

df[(mask5 & mask6) | mask7]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05 2019-01-31 06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16 2019-01-31 19:47:00  100705   16.961
# 387     Robert    Male 1994-10-29 2019-01-31 04:26:00  123294   19.894
# 451      Terry     NaN 2016-07-15 2019-01-31 00:29:00  140002   19.490
#
#      Senior Management             Team
# 15               False          Product
# 98                True        Marketing
# 387              False  Client Services
# 451               True        Marketing
