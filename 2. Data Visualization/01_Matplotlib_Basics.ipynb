# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [1, 2, 3, 4, 5, 6]
y = [1, 2, 3, 4, 5, 6]

# %%
plt.plot(x, y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Simple Matplotlib EXample')
plt.show()
