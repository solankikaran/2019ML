# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
time = np.arange(0.0, 2.0, 0.01)

c = 1 + np.cos(2* np.pi*time)

# %%
plt.plot(time, c, '*')
plt.grid()
plt.xlabel('Time(t)')
plt.ylabel('Voltage(mv)')
plt.title('Cosine Wave Plot')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
